# %%
import socket
import pyttsx3
engine=pyttsx3.init()
engine.say("welcome to ai application hello team one")
engine.runAndWait()
from voice_recognize import voice_recognize

print("\t\t\tAI PROJECT")
print("\t\t\t..........")

print(""" 1. press 1 to show date
 2. press 2 to show calculator
 3. press 3 to setup docker
 4. press 4 for setup webserver
 5. press 5 for hadoop
 6. press 6 for photo click
 7. press 7 to exit""")
print("enter choise")

s=socket.socket()
serverip="192.168.43.202"
serverport=1114
s.connect( (serverip,serverport) )


while True:
    ch = voice_recognize()
    print(ch)
    if "date" in ch or "get" in ch:
        cmd="1"
        cmd=cmd.encode()
        s.send(cmd)
        output=s.recv(200).decode()
        print(output)   
    elif "calculator" in ch or "calci" in ch:
        cmd="2"
        cmd=cmd.encode()
        s.send(cmd)
        output=s.recv(200).decode()
        print(output)
    elif "docker" in ch or "setup" in ch:
        cmd="3"
        cmd=cmd.encode()
        s.send(cmd)
        output=s.recv(200).decode()
        print(output)
    elif "web server" in ch or "setup" in ch:
        cmd="4"
        cmd=cmd.encode()
        s.send(cmd)
        output=s.recv(200).decode()
        print(output)
    elif "hadoop" in ch or "cluster" in ch:
        cmd="5"
        cmd=cmd.encode()
        s.send(cmd)
        output=s.recv(200).decode()
        print(output)
    elif "click" in ch or "photo" in ch:
        cmd="6"
        cmd=cmd.encode()
        s.send(cmd)
        output=s.recv(200).decode()
        print(output)
    else:
        print("could not understand")
